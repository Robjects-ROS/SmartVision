# %%
import cv2 

img = cv2.imread('yahboom.jpg', 1)
# cv2.imshow('image', img) 
# cv2.waitKey (0)

# %% [markdown]
# #After running the following program, the read image will be displayed in the jupyter Lab controls

# %%
import enum
import cv2

def bgr8_to_jpeg(value, quality=75):
    return bytes(cv2.imencode('.jpg', value)[1])

# %%
import ipywidgets.widgets as widgets

image_widget = widgets.Image(format='jpg', width=800, height=800)
display(image_widget)

image_widget.value = bgr8_to_jpeg(img)
# Out:
# Image(value=b'', format='jpg', height='800', width='800')
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-3-71844cfb2de2> in <module>
#       4 display(image_widget)
#       5
# ----> 6 image_widget.value = bgr8_to_jpeg(img)
#
# <ipython-input-2-ac2f8e5ddf67> in bgr8_to_jpeg(value, quality)
#       3
#       4 def bgr8_to_jpeg(value, quality=75):
# ----> 5     return bytes(cv2.imencode('.jpg', value)[1])
#
# error: OpenCV(4.8.1) /io/opencv/modules/imgcodecs/src/loadsave.cpp:1113: error: (-215:Assertion failed) !image.empty() in function 'imencode'
